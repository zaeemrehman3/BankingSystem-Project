# %% [markdown]
# # Banking System

# %%
# Banking System project using Python Functions.

# %% [markdown]
# #### Accounts Opening

# %%
import system

# %%
system.open_account()
# Out:
# Account title:  zaeem rehman
# Cnic no:  38299229
# Contact no:  39392929
# Initial Deposit:  4774489
# Your Account Opened!
# Your Account title is zaeem rehman and Account number is 27355

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355}]

# %%
system.open_account()
# Out:
# Account title:  husain khan
# Cnic no:  473893929
# Contact no:  478483839
# Initial Deposit:  5784949400
# Your Account Opened!
# Your Account title is husain khan and Account number is 72767

# %%
system.open_account()
# Out:
# Account title:  arquam owais
# Cnic no:  647438383
# Contact no:  56674884e8
# Initial Deposit:  4674838
# Your Account Opened!
# Your Account title is arquam owais and Account number is 51806

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355},
#  {'title': 'husain khan',
#   'cnic': '473893929',
#   'contact': '478483839',
#   'balance': 5784949400,
#   'account_number': 72767},
#  {'title': 'arquam owais',
#   'cnic': '647438383',
#   'contact': '56674884e8',
#   'balance': 4674838,
#   'account_number': 51806}]

# %% [markdown]
# #### Cash Deposit

# %%
system.cash_deposit(72767,10000)
# Out:
# Amount deposited Successfully

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355},
#  {'title': 'husain khan',
#   'cnic': '473893929',
#   'contact': '478483839',
#   'balance': 5784959400,
#   'account_number': 72767},
#  {'title': 'arquam owais',
#   'cnic': '647438383',
#   'contact': '56674884e8',
#   'balance': 4674838,
#   'account_number': 51806}]

# %%
system.cash_deposit(72867,10000)
# Out:
# Invalid Account Number!

# %% [markdown]
# #### Balance Check

# %%
system.check_balance(51806)
# Out:
# Your Account holding the balance of Rs: 4674838

# %%
system.check_balance(27355)
# Out:
# Your Account holding the balance of Rs: 4774489

# %%
system.check_balance(37355)
# Out:
# Invalid Account Number!

# %% [markdown]
# #### Cash Withdrawal

# %%
system.cash_withdrawal(51806,29223)
# Out:
# Here is your Amount of Rs: 29223

# %%
system.check_balance(51806)
# Out:
# Your Account holding the balance of Rs: 4616392

# %%
system.cash_withdrawal(56806,29223)
# Out:
# Invalid Account Number / or Insufficient Balance

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355},
#  {'title': 'husain khan',
#   'cnic': '473893929',
#   'contact': '478483839',
#   'balance': 5784959400,
#   'account_number': 72767},
#  {'title': 'arquam owais',
#   'cnic': '647438383',
#   'contact': '56674884e8',
#   'balance': 4616392,
#   'account_number': 51806}]

# %% [markdown]
# #### Accounts Closing

# %%
system.close_account(51806)
# Out:
# Here is your amount 4616392
# Your Acccount closed successfully

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355},
#  {'title': 'husain khan',
#   'cnic': '473893929',
#   'contact': '478483839',
#   'balance': 5784959400,
#   'account_number': 72767}]

# %%
system.check_balance(51806)
# Out:
# Invalid Account Number!

# %% [markdown]
# #### Transferring of Amount between Accounts

# %%
system.check_balance(72767)
# Out:
# Your Account holding the balance of Rs: 5784959400

# %%
system.check_balance(27355)
# Out:
# Your Account holding the balance of Rs: 4774489

# %%
system.transfer_amount(72767,500000,27355)
# Out:
# Amount Transferred!

# %%
system.Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '38299229',
#   'contact': '39392929',
#   'balance': 4774489,
#   'account_number': 27355},
#  {'title': 'husain khan',
#   'cnic': '473893929',
#   'contact': '478483839',
#   'balance': 5784959400,
#   'account_number': 72767}]
