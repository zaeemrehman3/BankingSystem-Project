# %% [markdown]
# # Banking System

# %%
Accounts = []

# %%
import random

# %%
def open_account():
    account_title = input("Account title: ")
    cnic = input("Cnic no: ")
    initial_deposit = int(input("Initial Deposit: "))
    account_number = random.radint(10000,99999)
# Out:
#   Cell In[11], line 4
#     account_title = input("Account title: ")
#     ^
# IndentationError: unexpected indent
