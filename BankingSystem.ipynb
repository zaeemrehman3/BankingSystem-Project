# %% [markdown]
# # Banking System

# %%
Accounts = []

# %%
import random

# %%
def open_account():
    account_title = input("Account title: ")
    cnic = input("Cnic no: ")
    contact = input("Contact no: ")
    initial_deposit = int(input("Initial Deposit: "))
    account_number = random.randint(10000,99999)
    account = {'title' : account_title,
               'cnic' : cnic,
               'contact' : contact,
               'balance' : initial_deposit,
               'account_number' : account_number}
    Accounts.append(account)
    print("Your Account Opened!")
    print(f"Your Account title is {account['title']} and Account number is {account['account_number']}")

# %%
open_account()
# Out:
# Account title:  zaeem rehman
# Cnic no:  31304404040
# Contact no:  3003032
# Initial Deposit:  292020238
# Your Account Opened!
# Your Account title is zaeem rehman and Account number is 71295

# %%
open_account()
# Out:
# Account title:  husain khan
# Cnic no:  3993992
# Contact no:  39932020
# Initial Deposit:  4848484
# Your Account Opened!
# Your Account title is husain khan and Account number is 85062

# %%
open_account()
# Out:
# Account title:  arquam owais
# Cnic no:  392902
# Contact no:  4839493
# Initial Deposit:  4894
# Your Account Opened!
# Your Account title is arquam owais and Account number is 36602

# %%
Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '31304404040',
#   'contact': '3003032',
#   'balance': 292020238,
#   'account_number': 71295},
#  {'title': 'husain khan',
#   'cnic': '3993992',
#   'contact': '39932020',
#   'balance': 4848484,
#   'account_number': 85062},
#  {'title': 'arquam owais',
#   'cnic': '392902',
#   'contact': '4839493',
#   'balance': 4894,
#   'account_number': 36602}]

# %%
def cash_deposit(acc_num, amount):
    if amount > 0:
        for acc in Accounts:
            if acc['account_number'] == acc_num:
                acc['balance'] += amount
                print("Amount deposited Successfully")
                break
        else:
            print("Invalid Account Number!")
    else:
        print("Invalid Amount!")

# %%
cash_deposit(85062,10000)
# Out:
# Amount deposited Successfully

# %%
Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '31304404040',
#   'contact': '3003032',
#   'balance': 292020238,
#   'account_number': 71295},
#  {'title': 'husain khan',
#   'cnic': '3993992',
#   'contact': '39932020',
#   'balance': 4878484,
#   'account_number': 85062},
#  {'title': 'arquam owais',
#   'cnic': '392902',
#   'contact': '4839493',
#   'balance': 4894,
#   'account_number': 36602}]

# %%
def check_balance(acc_num):
    for acc in Accounts:
            if acc['account_number'] == acc_num:
                print(f"Your Account holding the balance of Rs: {acc['balance']}")
                break
    else:
        print("Invalid Account Number!")

# %%
check_balance(36602)
# Out:
# Your Account holding the balance of Rs: 4894

# %%
check_balance(71295)
# Out:
# Your Account holding the balance of Rs: 292020238

# %%
def cash_withdrawal(acc_num, amount):
    for acc in Accounts:
            if (acc['account_number'] == acc_num) and (acc['balance'] >= amount):
                acc['balance'] -= amount
                print(f"Here is your Amount of Rs: {amount}")
                break
    else:
        print("Invalid Account Number / or Insufficient Balance")

# %%
cash_withdrawal(71295,29202023)
# Out:
# Here is your Amount of Rs: 29202023

# %%
check_balance(71295)
# Out:
# Your Account holding the balance of Rs: 262812715

# %%
def close_account(acc_num):
    for i,acc in enumerate(Accounts):
            if acc['account_number'] == acc_num:
                print(f"Here is your amount {acc['balance']}")
                acc['balance'] = 0
                del Accounts[i]
                print("Your Acccount closed successfully")
                break
    else:
        print("Invalid Account Number!")

# %%
close_account(85062)
# Out:
# Here is your amount 4878484
# Your Acccount closed successfully

# %%
Accounts
# Out:
# [{'title': 'zaeem rehman',
#   'cnic': '31304404040',
#   'contact': '3003032',
#   'balance': 262812715,
#   'account_number': 71295},
#  {'title': 'arquam owais',
#   'cnic': '392902',
#   'contact': '4839493',
#   'balance': 4894,
#   'account_number': 36602}]

# %%
check_balance(85062)
# Out:
# Invalid Account Number!

# %%
def transfer_amount(from_account, amount, to_account):
    for from_acc in Accounts:
        if from_acc['account_number'] == from_account:
            for to_acc in Accounts:
                if to_acc['account_number'] == to_account:
                    print("Amount Transferred!")
                    break
                else:
                    print("Invalid Amount reciever Account")
    else:
        print("Invalid Amount sender Account")

# %%
transfer_amount(36602,500,71295)
# Out:
# Invalid Amount sender Account
# Amount Transferred!
